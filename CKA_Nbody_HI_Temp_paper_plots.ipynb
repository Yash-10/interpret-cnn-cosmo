# %% [markdown]
# <a href="https://colab.research.google.com/github/Yash-10/CAMELS-CNN-Interpretability-using-CKA/blob/main/CKA_Nbody_HI_Temp_paper_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
from mpl_toolkits.axes_grid1 import make_axes_locatable

import seaborn as sns
sns.set_context("paper", font_scale = 2)
sns.set_style('whitegrid')
sns.set(style='ticks')

# %%
path = '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results'
glob.glob(path + '/*')
# Out:
# ['/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_32examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_64examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnTNGMaps_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnSIMBAMaps_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_TNGTrials_appliedOnTNGMaps_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_SIMBATrials_appliedOnSIMBAMaps_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnTNGMaps_16examples.npy',
#  '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnSIMBAMaps_16examples.npy',
# ...

# %%
# def visualize_cka(sim):
#   fig, ax = plt.subplots(1, 1, figsize=(5, 5))

#   divider = make_axes_locatable(ax)
#   cax = divider.append_axes('right', size='5%', pad=0.05)

#   im = ax.imshow(sim, cmap='magma')
#   layers = np.arange(1, 21, 2)
#   ax.set_xticks(layers); ax.set_yticks(layers)
#   ax.set_xticklabels(layers); ax.set_yticklabels(layers)
#   ax.axes.invert_yaxis()
#   fig.colorbar(im, cax=cax, orientation='vertical')
#   plt.show()

# %%
titlesize = 18
axeslabelsize = 16
ticklabelsize = 14

# %% [markdown]
# # Example maps

# %%
HI_simba = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/HI_simba_100_example.npy')
HI_tng = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/HI_tng_100_example.npy')
T_simba = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/T_simba_100_example.npy')
T_tng = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/T_tng_100_example.npy')
Nbody = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/Nbody_100_example.npy')
Nbody_simba = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/Nbody_simba_100_example.npy')

# Params
HI_simba_params = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/HI_simba_100_example_simParams.npy')
HI_tng_params = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/HI_tng_100_example_simParams.npy')
T_simba_params = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/T_simba_100_example_simParams.npy')
T_tng_params = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/T_tng_100_example_simParams.npy')
Nbody_params = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/Nbody_100_example_simParams.npy')

# %%
def log(x):
  return np.log(x)

fig, ax = plt.subplots(1, 4, figsize=(12, 9))
# im00 = ax[0, 0].imshow(log(Nbody), cmap='gray')
im01 = ax[0].imshow(log(HI_tng), cmap='viridis')
im02 = ax[1].imshow(log(T_tng), cmap='plasma')
# im10 = ax[1, 0].imshow(log(Nbody_simba), cmap='gray')
im11 = ax[2].imshow(log(HI_simba), cmap='viridis')
im12 = ax[3].imshow(log(T_simba), cmap='plasma')

ax[0].set_xticks([]); ax[1].set_xticks([]); ax[2].set_xticks([]); ax[3].set_xticks([])
ax[0].set_yticks([]); ax[1].set_yticks([]); ax[2].set_yticks([]); ax[3].set_yticks([])

# ax[0, 2].set_xticks([]); ax[0, 2].set_yticks([])
# ax[1, 0].set_xticks([]); ax[1, 0].set_yticks([])
# ax[1, 1].set_xticks([]); ax[1, 1].set_yticks([])
# ax[1, 2].set_xticks([]); ax[1, 2].set_yticks([])

# ax[0, 0].set_title(r'$N$-body', fontsize=titlesize)
ax[0].set_title('TNG - HI', fontsize=titlesize)
ax[1].set_title('TNG - Temp', fontsize=titlesize)
# ax[1, 0].set_title(r'$N$-body', fontsize=titlesize)
ax[2].set_title('SIMBA - HI', fontsize=titlesize)
ax[3].set_title('SIMBA - Temp', fontsize=titlesize)

# ax[0, 0].set_title(r'$N$-body' + r' $(\Omega_{\rm m}$' + ' = ' + f'{Nbody_params[0]:.2f},' + fr' $\sigma_8$ = {Nbody_params[1]:.2f})', fontsize=13)
# ax[0].set_title('HI - TNG' + r' $(\Omega_{\rm m}$' + ' = ' + f'{HI_tng_params[0]:.2f},' + fr' $\sigma_8$ = {HI_tng_params[1]:.2f})', fontsize=13)
# ax[1].set_title('Temp - TNG' + r' $(\Omega_{\rm m}$' + ' = ' + f'{T_tng_params[0]:.2f},' + fr' $\sigma_8$ = {T_tng_params[1]:.2f})', fontsize=13)
# ax[2].set_title('HI - SIMBA' + r' $(\Omega_{\rm m}$' + ' = ' + f'{HI_simba_params[0]:.2f},' + fr' $\sigma_8$ = {HI_simba_params[1]:.2f})', fontsize=13)
# ax[3].set_title('Temp - SIMBA' + r' $(\Omega_{\rm m}$' + ' = ' + f'{T_simba_params[0]:.2f},' + fr' $\sigma_8$ = {T_simba_params[1]:.2f})', fontsize=13)

# divider = make_axes_locatable(ax[0, 0])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im00, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[0, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im01, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[0, 2])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im02, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im11, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 2])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im12, cax=cax, orientation='vertical')

plt.tight_layout()

fig.subplots_adjust(hspace=0.13)

plt.savefig('example_maps.png', bbox_inches='tight', dpi=150)

# %% [markdown]
# # Nbody

# %%
nbody16 = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_16examples.npy')
nbody32 = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_32examples.npy')
nbody64 = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_64examples.npy')

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
im0 = ax[0].imshow(nbody16, vmin=0., vmax=1.)
im1 = ax[1].imshow(nbody32, vmin=0., vmax=1.)
im2 = ax[2].imshow(nbody64, vmin=0., vmax=1.)

layers = np.arange(1, 21, 3)
ax[0].set_xticks(layers); ax[0].set_yticks(layers)
ax[0].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[0].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[0].axes.invert_yaxis()
# ax[0].set_title(f'16 examples ($R^2 = {np.round(0.997492295561833, 3)}, {np.round(0.9873676364158052, 3)}$)', fontsize=titlesize)
ax[0].set_title(f'16 examples', fontsize=titlesize)
ax[0].set_ylabel('Layers Model 1', fontsize=axeslabelsize)
ax[0].set_xlabel('Layers Model 2', fontsize=axeslabelsize)
# fig.colorbar(im0, cax=cax, orientation='vertical')

layers = np.arange(1, 21, 3)
ax[1].set_xticks(layers); ax[1].set_yticks(layers)
ax[1].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[1].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[1].axes.invert_yaxis()
ax[1].set_title('32 examples', fontsize=titlesize)
# ax[1].set_ylabel('Layers Model 1', fontsize=axeslabelsize)
ax[1].set_xlabel('Layers Model 2', fontsize=axeslabelsize)
# fig.colorbar(im1, cax=cax, orientation='vertical')

layers = np.arange(1, 21, 3)
ax[2].set_xticks(layers); ax[2].set_yticks(layers)
ax[2].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[2].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[2].axes.invert_yaxis()
ax[2].set_title('64 examples', fontsize=titlesize)
# ax[2].set_ylabel('Layers Model 1', fontsize=axeslabelsize)
ax[2].set_xlabel('Layers Model 2', fontsize=axeslabelsize)
# fig.colorbar(im2, cax=cax, orientation='vertical')

ax[1].set_yticks([]); ax[2].set_yticks([])

plt.tight_layout()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.81, 0.19, 0.01, 0.68])
fig.colorbar(im2, cax=cbar_ax)

plt.savefig('nbody_batch_example.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# # HI

# %%
names = [
     '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnTNGMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnSIMBAMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnTNGMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnSIMBAMaps_16examples.npy'
]

hi_tng_tng_omegam_r2 = np.round(0.99345986376, 2)
hi_tng_tng_omegam_rmse = np.round(0.00058030875, 2)
hi_tng_simba_omegam_r2 = np.round(0.60415589274, 2)
hi_tng_simba_omegam_rmse = np.round(0.0299446075, 2)
hi_simba_tng_omegam_r2 = np.round(0.76652844213, 2)
hi_simba_tng_omegam_rmse = np.round(0.020716019, 2)
hi_simba_simba_omegam_r2 = np.round(0.98025666079, 2)
hi_simba_simba_omegam_rmse = np.round(0.00149353385, 2)

hi_tng_tng_sigma8_r2 = np.round(0.95924302563, 2)
hi_tng_tng_sigma8_rmse = np.round(0.00362154885, 2)
hi_tng_simba_sigma8_r2 = np.round(-0.16080379444, 2)
hi_tng_simba_sigma8_rmse = np.round(0.100815595, 2)
hi_simba_tng_sigma8_r2 = np.round(0.3058667552, 2)
hi_simba_tng_sigma8_rmse = np.round(0.0616787075, 2)
hi_simba_simba_sigma8_r2 = np.round(0.87211161352, 2)
hi_simba_simba_sigma8_rmse = np.round(0.0111070825, 2)

fig, ax = plt.subplots(2, 2, figsize=(9, 7))
im00 = ax[0, 0].imshow(np.load(names[0]), cmap='magma', vmin=0., vmax=1.)
im01 = ax[0, 1].imshow(np.load(names[1]), cmap='magma', vmin=0., vmax=1.)
im11 = ax[1, 0].imshow(np.load(names[2]), cmap='magma', vmin=0., vmax=1.)
im12 = ax[1, 1].imshow(np.load(names[3]), cmap='magma', vmin=0., vmax=1.)

layers = np.arange(1, 21, 3)
ax[0, 0].set_xticks(layers); ax[0, 0].set_yticks(layers)
ax[0, 0].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[0, 0].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[0, 0].axes.invert_yaxis()

ax[0, 1].set_xticks(layers); ax[0, 1].set_yticks(layers)
ax[0, 1].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[0, 1].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[0, 1].axes.invert_yaxis()

ax[1, 0].set_xticks(layers); ax[1, 0].set_yticks(layers)
ax[1, 0].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[1, 0].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[1, 0].axes.invert_yaxis()

ax[1, 1].set_xticks(layers); ax[1, 1].set_yticks(layers)
ax[1, 1].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[1, 1].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[1, 1].axes.invert_yaxis()

ax[0, 0].set_title(r'TNG-TNG: $R^{2}(\Omega_{\rm m})=$' + f'{hi_tng_tng_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{hi_tng_tng_sigma8_r2}', fontsize=10)
ax[0, 1].set_title(r'TNG-SIMBA: $R^{2}(\Omega_{\rm m})=$' + f'{hi_tng_simba_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{hi_tng_simba_sigma8_r2}', fontsize=10)
ax[1, 0].set_title(r'SIMBA-TNG: $R^{2}(\Omega_{\rm m})=$' + f'{hi_simba_tng_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{hi_simba_tng_sigma8_r2}', fontsize=10)
ax[1, 1].set_title(r'SIMBA-SIMBA: $R^{2}(\Omega_{\rm m})=$' + f'{hi_simba_simba_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{hi_simba_simba_sigma8_r2}', fontsize=10)

ax[0, 0].set_xticks([])
ax[0, 1].set_yticks([]); ax[0, 1].set_xticks([])
ax[1, 1].set_yticks([])

plt.tight_layout()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.8, 0.16, 0.03, 0.68])
cbar = fig.colorbar(im12, cax=cbar_ax)

cbar.set_label('Similarity (CKA)', rotation=270, labelpad=18, fontsize=16)

fig.text(0.32, 0.0005, 'Layers Model 2', fontsize=axeslabelsize)
fig.text(0.0005, 0.39, 'Layers Model 1', fontsize=axeslabelsize, rotation='vertical')

# divider = make_axes_locatable(ax[0, 0])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im00, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[0, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im01, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 0])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im11, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im12, cax=cax, orientation='vertical')

plt.savefig('HI_results.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# TODO: Try:
#
# ```
# r’$R^{2}(\Omega_{\rm m})=0.8, R^{2}(\sigma{8})=0.8$’
#
# R^{2}=(0.8,0.8)
# ```

# %% [markdown]
# # Temp

# %%
names = [
     '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_TNGTrials_appliedOnTNGMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_TNGTrials_appliedOnSIMBAMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_SIMBATrials_appliedOnTNGMaps_16examples.npy',
    '/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_SIMBATrials_appliedOnSIMBAMaps_16examples.npy',
]

temp_tng_tng_omegam_r2 = np.round(0.99163668695, 2)
# temp_tng_tng_omegam_rmse = np.round(, 3)
temp_tng_simba_omegam_r2 = np.round(0.13750108104, 2)
# temp_tng_simba_omegam_rmse = np.round(, 3)
temp_simba_tng_omegam_r2 = np.round(0.25249493323, 2)
# temp_simba_tng_omegam_rmse = np.round(, 3)
temp_simba_simba_omegam_r2 = np.round(0.90798139613, 2)
# temp_simba_simba_omegam_rmse = np.round(, 3)

temp_tng_tng_sigma8_r2 = np.round(0.96372156061, 2)
# temp_tng_tng_sigma8_rmse = np.round(, 3)
temp_tng_simba_sigma8_r2 = np.round(-15.4538266996, 2)
# temp_tng_simba_sigma8_rmse = np.round(, 3)
temp_simba_tng_sigma8_r2 = np.round(-1.49845313219, 2)
# temp_simba_tng_sigma8_rmse = np.round(, 3)
temp_simba_simba_sigma8_r2 = np.round(0.71118109563, 2)
# temp_simba_simba_sigma8_rmse = np.round(, 3)

fig, ax = plt.subplots(2, 2, figsize=(9, 7))
im00 = ax[0, 0].imshow(np.load(names[0]), cmap='magma', vmin=0., vmax=1.)
im01 = ax[0, 1].imshow(np.load(names[1]), cmap='magma', vmin=0., vmax=1.)
im11 = ax[1, 0].imshow(np.load(names[2]), cmap='magma', vmin=0., vmax=1.)
im12 = ax[1, 1].imshow(np.load(names[3]), cmap='magma', vmin=0., vmax=1.)

layers = np.arange(1, 21, 3)
ax[0, 0].set_xticks(layers); ax[0, 0].set_yticks(layers)
ax[0, 0].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[0, 0].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[0, 0].axes.invert_yaxis()

ax[0, 1].set_xticks(layers); ax[0, 1].set_yticks(layers)
ax[0, 1].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[0, 1].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[0, 1].axes.invert_yaxis()

ax[1, 0].set_xticks(layers); ax[1, 0].set_yticks(layers)
ax[1, 0].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[1, 0].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[1, 0].axes.invert_yaxis()

ax[1, 1].set_xticks(layers); ax[1, 1].set_yticks(layers)
ax[1, 1].set_xticklabels(layers+1, fontsize=ticklabelsize); ax[1, 1].set_yticklabels(layers+1, fontsize=ticklabelsize)
ax[1, 1].axes.invert_yaxis()

ax[0, 0].set_title(r'TNG-TNG: $R^{2}(\Omega_{\rm m})=$' + f'{temp_tng_tng_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{temp_tng_tng_sigma8_r2}', fontsize=10)
ax[0, 1].set_title(r'TNG-SIMBA: $R^{2}(\Omega_{\rm m})=$' + f'{temp_tng_simba_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{temp_tng_simba_sigma8_r2}', fontsize=10)
ax[1, 0].set_title(r'SIMBA-TNG: $R^{2}(\Omega_{\rm m})=$' + f'{temp_simba_tng_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{temp_simba_tng_sigma8_r2}', fontsize=10)
ax[1, 1].set_title(r'SIMBA-SIMBA: $R^{2}(\Omega_{\rm m})=$' + f'{temp_simba_simba_omegam_r2}, ' + r'$R^{2}(\sigma_8)=$' + f'{temp_simba_simba_sigma8_r2}', fontsize=10)

ax[0, 0].set_xticks([])
ax[0, 1].set_yticks([]); ax[0, 1].set_xticks([])
ax[1, 1].set_yticks([])

plt.tight_layout()

fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.8, 0.16, 0.03, 0.68])
cbar = fig.colorbar(im12, cax=cbar_ax)

cbar.set_label('Similarity (CKA)', rotation=270, labelpad=18, fontsize=16)

fig.text(0.32, 0.0005, 'Layers Model 2', fontsize=axeslabelsize)
fig.text(0.0005, 0.39, 'Layers Model 1', fontsize=axeslabelsize, rotation='vertical')

# divider = make_axes_locatable(ax[0, 0])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im00, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[0, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im01, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 0])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im11, cax=cax, orientation='vertical')

# divider = make_axes_locatable(ax[1, 1])
# cax = divider.append_axes('right', size='5%', pad=0.05)
# fig.colorbar(im12, cax=cax, orientation='vertical')

plt.savefig('Temp_results.png', bbox_inches='tight', dpi=250)

# %% [markdown]
# # Extra

# %%
files = glob.glob('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI*.npy')

diagonal_means = []
off_diagonal_means = []
means = []
x = []
for f in files:
  print(f)
  arr = np.load(f)
  diagonal_means.append(np.mean(np.diagonal(arr)))
  off_diagonal_means.append((arr.sum() - np.diagonal(arr).sum()) / (arr.shape[0]**2 - arr.shape[0]))
  means.append(np.mean(arr))
  x.append(
      (arr - np.mean(arr)).mean()
  )

diagonal_means = np.array(diagonal_means)
off_diagonal_means = np.array(off_diagonal_means)

r2_omegam = np.array([0.99, 0.98, 0.77, 0.6])
r2_sigma8 = np.array([0.96, 0.87, 0.31, -0.16])

# val = (arr / np.mean(arr)).mean()
val = diagonal_means/off_diagonal_means
print(np.round(diagonal_means, 2))
print(np.round(off_diagonal_means, 2))
# val = means

plt.plot(val, r2_omegam, linestyle='--', marker='o'); plt.xlabel('Diagonal Similarity'); plt.ylabel(r'$R^2$'); plt.title(r'$\Omega_m$'); plt.show()
plt.plot(val, r2_sigma8, linestyle='--', marker='o'); plt.xlabel('Diagonal Similarity'); plt.ylabel(r'$R^2$'); plt.title(r'$\sigma_8$'); plt.show()
# Out:
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnTNGMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnSIMBAMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_SIMBATrials_appliedOnTNGMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_HI_TNGTrials_appliedOnSIMBAMaps_16examples.npy
# [0.94 0.96 0.95 0.93]
# [0.63 0.56 0.63 0.63]

# %%
files = glob.glob('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T*.npy')

diagonal_means = []
off_diagonal_means = []
means = []

for f in files:
  print(f)
  arr = np.load(f)
  diagonal_means.append(np.mean(np.diagonal(arr)))
  off_diagonal_means.append((arr.sum() - np.diagonal(arr).sum()) / (arr.shape[0]**2 - arr.shape[0]))
  means.append(np.mean(arr))

diagonal_means = np.array(diagonal_means)
off_diagonal_means = np.array(off_diagonal_means)

r2_omegam = np.array([0.99, 0.91, 0.25, 0.14])
r2_sigma8 = np.array([0.96, 0.71, -1.5, -15.45])

val = means
# print(val)
print(np.round(diagonal_means, 2))
print(np.round(off_diagonal_means, 2))
# val = means

plt.plot(val, r2_omegam, linestyle='--', marker='o'); plt.xlabel('Diagonal Similarity'); plt.ylabel(r'$R^2$'); plt.title(r'$\Omega_m$'); plt.show()
plt.plot(val, r2_sigma8, linestyle='--', marker='o'); plt.xlabel('Diagonal Similarity'); plt.ylabel(r'$R^2$'); plt.title(r'$\sigma_8$'); plt.show()
# Out:
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_TNGTrials_appliedOnTNGMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_SIMBATrials_appliedOnSIMBAMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_SIMBATrials_appliedOnTNGMaps_16examples.npy
# /content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_T_TNGTrials_appliedOnSIMBAMaps_16examples.npy
# [0.96 0.92 0.92 0.93]
# [0.61 0.5  0.64 0.69]

# %%
import numpy as np

cka = np.load('/content/drive/MyDrive/CAMELS/CKA_matrices_and_results/cka_nbody_tng_16examples.npy')
x = np.linalg.eig(cka)
len(x)
# Out:
# 2

# %%
import matplotlib.pyplot as plt
plt.plot(x[0])
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
def check_symmetric(a, rtol=1e-05, atol=1e-08):
    return np.allclose(a, a.T, rtol=rtol, atol=atol)

check_symmetric(cka)
# Out:
# False

# %%
cka, cka.T
# Out:
# (array([[0.99819721, 0.90781436, 0.76745845, 0.8923419 , 0.91463616,
#          0.90674607, 0.89806021, 0.8993151 , 0.87189082, 0.85387568,
#          0.83720559, 0.77912219, 0.76580428, 0.72362642, 0.68842233,
#          0.66634037, 0.6874308 , 0.63293966, 0.52389659, 0.52922278,
#          0.49039336],
#         [0.94305153, 0.97874083, 0.86833437, 0.90751658, 0.87407521,
#          0.87573636, 0.85584598, 0.8437395 , 0.82341642, 0.80560714,
#          0.78626962, 0.72996146, 0.70706625, 0.65028952, 0.62022476,
#          0.60321913, 0.63532838, 0.60968268, 0.4865638 , 0.472996  ,
#          0.43241829],
#         [0.81084761, 0.94692187, 0.92467616, 0.87784037, 0.79888804,
#          0.80103213, 0.77984849, 0.7639464 , 0.754443  , 0.73885248,
#          0.72443488, 0.68594885, 0.66778779, 0.6140539 , 0.59462063,
#          0.578617  , 0.60893767, 0.605863  , 0.51187678, 0.48873871,
#          0.44871727],
#         [0.80747537, 0.9006635 , 0.87280369, 0.86478802, 0.83506387,
# ...
